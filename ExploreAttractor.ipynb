# %% [markdown]
# # Runge-Kutta and Euler Methods
#    # An experiement to answer the following questions
#     1. How does the plotted solution depend on your choice of time step size, and
#     your choice of increment? Do you see an improvement in precision from
#     using the higher-order integration methods?
#     2. How does the solution depend upon the initial conditions [x0, y0, z0]? How
#     small a change can you make while still reproducing roughly the same
#     dynamical curves?

# %% [markdown]
#     # For the first example, the program is run with the following scenario :-
#         A) We run the program for Euler & order 4 methods. The time range is 0 to 100 and the step size is 100 & 10000.
#             a) Euler method, step size 100
#             b) Order 4 method, step size 100
#             c) Euler method, step size 10000
#             d) Order 4 method, step size 10000
#         B) We run the program for Euler & order 4 methods. The time range is 0 to 1000 and the step size is 100 & 10000.
#             a) Euler method, step size 100
#             b) Order 4 method, step size 100
#             c) Euler method, step size 10000
#             d) Order 4 method, step size 10000
#      # Based on the analysis we find there is higher precision when leveraging higher order integration methods.

# %%
from attractor import Attractor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()

# %%
from attractor import Attractor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()

# %%
from attractor import Attractor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()

# %%
from attractor import Attractor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()

# %% [markdown]
#     # For the second example, we run the program with the following scenarios :-
#         A) Initial value of 0.0,1.0,1.5 for Eulter & order 4
#         B) Inital value of 10.0, 15.0,20.0 for Eulter & order 4
#     # Based on the analysis the concentration of the rings is higher when chan

# %%
from attractor import Attractor

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()

# %%
from attractor import Attractor

a = Attractor()
a.evolve(order=1)
a.plotxy()
a.plotyz()
a.plotzx()
a.plot3d()
b = Attractor()
b.evolve(order=4)
b.plotxy()
b.plotyz()
b.plotzx()
b.plot3d()
